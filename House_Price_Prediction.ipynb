# %% [markdown]
# <a href="https://colab.research.google.com/github/roybibek/regression_modeling/blob/master/House_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pa
import numpy as np
import sklearn

# %%
url2 = "https://raw.githubusercontent.com/roybibek/regression_modeling/master/train.csv"
data = pa.read_csv(url2)

url3 = "https://raw.githubusercontent.com/roybibek/regression_modeling/master/test.csv"
testdata = pa.read_csv(url3)

# %%
data
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
data.head(1)
testdata.head(1)
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
#
# [1 rows x 80 columns]

# %%
data.iloc[:,6].describe()
# Out:
# count       91
# unique       2
# top       Grvl
# freq        50
# Name: Alley, dtype: object

# %%
data.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
 y = np.array(data['SalePrice'])
 y
# Out:
# array([208500, 181500, 223500, ..., 266500, 142125, 147500])

# %%
data.pop('SalePrice')
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
data
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0        1          60       RL  ...    2008        WD        Normal
# 1        2          20       RL  ...    2007        WD        Normal
# 2        3          60       RL  ...    2008        WD        Normal
# 3        4          70       RL  ...    2006        WD       Abnorml
# 4        5          60       RL  ...    2008        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1455  1456          60       RL  ...    2007        WD        Normal
# 1456  1457          20       RL  ...    2010        WD        Normal
# 1457  1458          70       RL  ...    2010        WD        Normal
# 1458  1459          20       RL  ...    2010        WD        Normal
# 1459  1460          20       RL  ...    2008        WD        Normal
#
# [1460 rows x 80 columns]

# %%
# Checking Categorical Data
data.select_dtypes(include=['object']).columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
# Checking Numerical Data
data.select_dtypes(include=['int64','float64']).columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold'],
#       dtype='object')

# %%
# getting information about missing values
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
missing_data = pa.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data[total > 0]
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageYrBlt      81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtExposure     38  0.026027
# BsmtFinType2     38  0.026027
# BsmtCond         37  0.025342
# BsmtQual         37  0.025342
# BsmtFinType1     37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685

# %%
# Now the task is to full NAN values with mode of the colum for some colums(Not all colums) all that value is appearing frequently .
for col in ['SaleType', 'KitchenQual', 'Exterior2nd', 'Exterior1st', 'Electrical', 'Functional', 'MSZoning']:
  data[col]=data[col].fillna(data[col].mode()[0])

#Fill NaN with Zero
for col in ['LotFrontage','BsmtFinSF1', 'BsmtFinSF2' , 'GarageCars' , 'GarageArea' , 'TotalBsmtSF' , 'BsmtUnfSF' , 'BsmtHalfBath' , 'BsmtFullBath' , 'MasVnrArea','GarageYrBlt' ]:
    data[col]=data[col].fillna(0)


# fill NaN with None
for col in ['MasVnrType','FireplaceQu' , 'Fence' , 'PoolQC' , 'MiscFeature' ,'Alley' , 'BsmtFinType1', 'BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'GarageType', 'GarageFinish' , 'GarageCond' , 'GarageQual'] :
    data[col]=data[col].fillna('None')   


for col in ['SaleType', 'KitchenQual', 'Exterior2nd', 'Exterior1st', 'Electrical', 'Functional', 'MSZoning']:
  testdata[col]=testdata[col].fillna(testdata[col].mode()[0])

#Fill NaN with Zero
for col in ['LotFrontage','BsmtFinSF1', 'BsmtFinSF2' , 'GarageCars' , 'GarageArea' , 'TotalBsmtSF' , 'BsmtUnfSF' , 'BsmtHalfBath' , 'BsmtFullBath' , 'MasVnrArea','GarageYrBlt' ]:
    testdata[col]=testdata[col].fillna(0)


# fill NaN with None
for col in ['MasVnrType','FireplaceQu' , 'Fence' , 'PoolQC' , 'MiscFeature' ,'Alley' , 'BsmtFinType1', 'BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'GarageType', 'GarageFinish' , 'GarageCond' , 'GarageQual','Utilities'] :
    testdata[col]=testdata[col].fillna('None')

# %%
data
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0        1          60       RL  ...    2008        WD        Normal
# 1        2          20       RL  ...    2007        WD        Normal
# 2        3          60       RL  ...    2008        WD        Normal
# 3        4          70       RL  ...    2006        WD       Abnorml
# 4        5          60       RL  ...    2008        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1455  1456          60       RL  ...    2007        WD        Normal
# 1456  1457          20       RL  ...    2010        WD        Normal
# 1457  1458          70       RL  ...    2010        WD        Normal
# 1458  1459          20       RL  ...    2010        WD        Normal
# 1459  1460          20       RL  ...    2008        WD        Normal
#
# [1460 rows x 80 columns]

# %%
data.info()
testdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1460 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            1460 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
url = "https://raw.githubusercontent.com/roybibek/regression_modeling/master/data_description1.txt"

print(url)
# Out:
# https://raw.githubusercontent.com/roybibek/regression_modeling/master/data_description1.txt

# %%
data.iloc[:,1]
#(data.iloc[:,1]==50)*1
# Out:
# 0       60
# 1       20
# 2       60
# 3       70
# 4       60
#         ..
# 1455    60
# 1456    20
# 1457    70
# 1458    20
# 1459    20
# Name: MSSubClass, Length: 1460, dtype: int64

# %%
import sklearn.preprocessing

le = sklearn.preprocessing.LabelEncoder()
modified = le.fit_transform(data.iloc[:,1])
hot = sklearn.preprocessing.OneHotEncoder()
hot2 = hot.fit_transform(modified.reshape(-1,1))

# %%
print(hot2)
# Out:
#   (0, 5)	1.0
#   (1, 0)	1.0
#   (2, 5)	1.0
#   (3, 6)	1.0
#   (4, 5)	1.0
#   (5, 4)	1.0
#   (6, 0)	1.0
#   (7, 5)	1.0
#   (8, 4)	1.0
#   (9, 14)	1.0
#   (10, 0)	1.0
#   (11, 5)	1.0
#   (12, 0)	1.0
#   (13, 0)	1.0
#   (14, 0)	1.0
#   (15, 3)	1.0
#   (16, 0)	1.0
#   (17, 10)	1.0
#   (18, 0)	1.0
#   (19, 0)	1.0
#   (20, 5)	1.0
#   (21, 3)	1.0
#   (22, 0)	1.0
#   (23, 11)	1.0
#   (24, 0)	1.0
#   :	:
#   (1435, 0)	1.0
#   (1436, 0)	1.0
#   (1437, 0)	1.0
#   (1438, 0)	1.0
#   (1439, 5)	1.0
#   (1440, 6)	1.0
#   (1441, 11)	1.0
#   (1442, 5)	1.0
#   (1443, 1)	1.0
#   (1444, 0)	1.0
#   (1445, 9)	1.0
#   (1446, 0)	1.0
#   (1447, 5)	1.0
#   (1448, 4)	1.0
#   (1449, 13)	1.0
#   (1450, 10)	1.0
#   (1451, 0)	1.0
#   (1452, 13)	1.0
#   (1453, 0)	1.0
#   (1454, 0)	1.0
#   (1455, 5)	1.0
#   (1456, 0)	1.0
#   (1457, 6)	1.0
#   (1458, 0)	1.0
#   (1459, 0)	1.0

# %%
import numpy as np

col = np.array(data)
hot = sklearn.preprocessing.OneHotEncoder(categories='auto')
hot2 = hot.fit_transform(col)

hot2.shape
# Out:
# (1460, 9105)

# %%
hot2
# Out:
# <1460x9105 sparse matrix of type '<class 'numpy.float64'>'
# 	with 116800 stored elements in Compressed Sparse Row format>

# %%
data.describe()
# Out:
#                 Id   MSSubClass  ...       MoSold       YrSold
# count  1460.000000  1460.000000  ...  1460.000000  1460.000000
# mean    730.500000    56.897260  ...     6.321918  2007.815753
# std     421.610009    42.300571  ...     2.703626     1.328095
# min       1.000000    20.000000  ...     1.000000  2006.000000
# 25%     365.750000    20.000000  ...     5.000000  2007.000000
# 50%     730.500000    50.000000  ...     6.000000  2008.000000
# 75%    1095.250000    70.000000  ...     8.000000  2009.000000
# max    1460.000000   190.000000  ...    12.000000  2010.000000
#
# [8 rows x 37 columns]

# %%
Lot = np.array(data["LotFrontage"]).reshape(-1, 1)

minmax = sklearn.preprocessing.MinMaxScaler()
minmax.fit_transform(Lot)
# Out:
# array([[0.20766773],
#        [0.25559105],
#        [0.2172524 ],
#        ...,
#        [0.21086262],
#        [0.2172524 ],
#        [0.23961661]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

def plot_correlation_map( df ):
    corr = data.corr()
    _ , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    _ = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = False, 
        annot_kws = { 'fontsize' : 14 })

# %%
plot_correlation_map(data)

# %% [markdown]
# **Feature Engineering**

# %%
 #find categorical variables names
categorical = [var for var in data.columns if data[var].dtype=='O']
print('There are {} categorical variables'.format(len(categorical)))
# Out:
# There are 43 categorical variables

# %%
# find numerical variables names
numerical = [var for var in data.columns if data[var].dtype!='O']
print('There are {} numerical variables'.format(len(numerical)))
# Out:
# There are 37 numerical variables

# %%
col = np.array(data[categorical])
hot = sklearn.preprocessing.OneHotEncoder(categories='auto')
hot2 = hot.fit_transform(col)

testcol = np.array(testdata[categorical])


hot2.shape
# Out:
# (1460, 266)

# %%
numerical.pop(0)
# Out:
# 'Id'

# %%
hot2
np.array(data[numerical]).shape
# Out:
# (1460, 36)

# %%
np.concatenate((np.array(data[numerical]),hot2.todense()),axis = 1)
# Out:
# matrix([[6.000e+01, 6.500e+01, 8.450e+03, ..., 0.000e+00, 1.000e+00,
#          0.000e+00],
#         [2.000e+01, 8.000e+01, 9.600e+03, ..., 0.000e+00, 1.000e+00,
#          0.000e+00],
#         [6.000e+01, 6.800e+01, 1.125e+04, ..., 0.000e+00, 1.000e+00,
#          0.000e+00],
#         ...,
#         [7.000e+01, 6.600e+01, 9.042e+03, ..., 0.000e+00, 1.000e+00,
#          0.000e+00],
#         [2.000e+01, 6.800e+01, 9.717e+03, ..., 0.000e+00, 1.000e+00,
#          0.000e+00],
#         [2.000e+01, 7.500e+01, 9.937e+03, ..., 0.000e+00, 1.000e+00,
#          0.000e+00]])

# %%
# let's visualise the values of the discrete variables
discrete = []
for var in numerical:
    if len(data[var].unique())<20:
        print(var, ' values: ', data[var].unique())
        discrete.append(var)
        
print('There are {} discrete variables'.format(len(discrete)))
# Out:
# MSSubClass  values:  [ 60  20  70  50 190  45  90 120  30  85  80 160  75 180  40]
# OverallQual  values:  [ 7  6  8  5  9  4 10  3  1  2]
# OverallCond  values:  [5 8 6 7 4 2 3 9 1]
# BsmtFullBath  values:  [1 0 2 3]
# BsmtHalfBath  values:  [0 1 2]
# FullBath  values:  [2 1 3 0]
# HalfBath  values:  [1 0 2]
# BedroomAbvGr  values:  [3 4 1 2 0 5 6 8]
# KitchenAbvGr  values:  [1 2 3 0]
# TotRmsAbvGrd  values:  [ 8  6  7  9  5 11  4 10 12  3  2 14]
# Fireplaces  values:  [0 1 2 3]
# GarageCars  values:  [2 3 1 0 4]
# PoolArea  values:  [  0 512 648 576 555 480 519 738]
# MoSold  values:  [ 2  5  9 12 10  8 11  4  1  7  3  6]
# YrSold  values:  [2008 2007 2006 2009 2010]
# There are 15 discrete variables

# %%
# let's visualise the percentage of missing values
for var in data.columns:
    if data[var].isnull().sum()>0:
        print(var, data[var].isnull().mean())

# %%
# let's inspect the type of those variables with a lot of missing information
for var in data.columns:
    if data[var].isnull().mean()>0.80:
        print(var, data[var].unique())

# %%
# first we make a list of continuous variables (from the numerical ones)
continuous = [var for var in numerical if var not in discrete and var not in ['Id', 'SalePrice']]
continuous
# Out:
# ['LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'GarageYrBlt',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'MiscVal']

# %%
# let's make boxplots to visualise outliers in the continuous variables 
# and histograms to get an idea of the distribution

for var in continuous:
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    fig = sns.boxplot(y=data[var])
    fig.set_title('')
    fig.set_ylabel(var)
    
    plt.subplot(1, 2, 2)
    fig = sns.distplot(data[var].dropna())
    fig.set_ylabel('Number of houses')
    fig.set_xlabel(var)

    plt.show()

# %%
# let's look at the distribution of the target variable

plt.figure(figsize=(15,6))
plt.subplot(1, 2, 1)
fig = sns.boxplot(y=y)
fig.set_title('Sale Price')
fig.set_ylabel(var)

plt.subplot(1, 2, 2)
fig = sns.distplot(y)#.hist(bins=20)
fig.set_ylabel('Frequency')
fig.set_xlabel('Sale Price')

plt.show()

# %%
# outlies in discrete variables
for var in discrete:
    print(data[var].value_counts() / np.float(len(data)))
    print()
# Out:
# 20     0.367123
# 60     0.204795
# 50     0.098630
# 120    0.059589
# 30     0.047260
# 160    0.043151
# 70     0.041096
# 80     0.039726
# 90     0.035616
# 190    0.020548
# 85     0.013699
# 75     0.010959
# 45     0.008219
# 180    0.006849
# 40     0.002740
# Name: MSSubClass, dtype: float64
#
# 5     0.271918
# 6     0.256164
# 7     0.218493
# 8     0.115068
# 4     0.079452
# 9     0.029452
# 3     0.013699
# 10    0.012329
# 2     0.002055
# 1     0.001370
# Name: OverallQual, dtype: float64
#
# 5    0.562329
# 6    0.172603
# 7    0.140411
# 8    0.049315
# 4    0.039041
# 3    0.017123
# 9    0.015068
# 2    0.003425
# 1    0.000685
# Name: OverallCond, dtype: float64
#
# 0    0.586301
# 1    0.402740
# 2    0.010274
# 3    0.000685
# Name: BsmtFullBath, dtype: float64
#
# 0    0.943836
# 1    0.054795
# 2    0.001370
# Name: BsmtHalfBath, dtype: float64
#
# 2    0.526027
# 1    0.445205
# 3    0.022603
# 0    0.006164
# Name: FullBath, dtype: float64
#
# ...

# %%
for var in categorical:
    print(var, ' contains ', len(data[var].unique()), ' labels')
# Out:
# MSZoning  contains  5  labels
# Street  contains  2  labels
# Alley  contains  3  labels
# LotShape  contains  4  labels
# LandContour  contains  4  labels
# Utilities  contains  2  labels
# LotConfig  contains  5  labels
# LandSlope  contains  3  labels
# Neighborhood  contains  25  labels
# Condition1  contains  9  labels
# Condition2  contains  8  labels
# BldgType  contains  5  labels
# HouseStyle  contains  8  labels
# RoofStyle  contains  6  labels
# RoofMatl  contains  8  labels
# Exterior1st  contains  15  labels
# Exterior2nd  contains  16  labels
# MasVnrType  contains  4  labels
# ExterQual  contains  4  labels
# ExterCond  contains  5  labels
# Foundation  contains  6  labels
# BsmtQual  contains  5  labels
# BsmtCond  contains  5  labels
# BsmtExposure  contains  5  labels
# BsmtFinType1  contains  7  labels
# BsmtFinType2  contains  7  labels
# Heating  contains  6  labels
# HeatingQC  contains  5  labels
# CentralAir  contains  2  labels
# ...

# %%
# one hot encoding 
one_hot_encoded_data = pa.get_dummies(data)
one_hot_encoded_data

test_hot_encoded_data = pa.get_dummies(testdata)
test_hot_encoded_data
# Out:
#         Id  MSSubClass  ...  SaleCondition_Normal  SaleCondition_Partial
# 0     1461          20  ...                     1                      0
# 1     1462          20  ...                     1                      0
# 2     1463          60  ...                     1                      0
# 3     1464          60  ...                     1                      0
# 4     1465         120  ...                     1                      0
# ...    ...         ...  ...                   ...                    ...
# 1454  2915         160  ...                     1                      0
# 1455  2916         160  ...                     0                      0
# 1456  2917          20  ...                     0                      0
# 1457  2918          85  ...                     1                      0
# 1458  2919          60  ...                     1                      0
#
# [1459 rows x 286 columns]

# %%
# inner join
final_train, final_test = one_hot_encoded_data.align(test_hot_encoded_data, join='inner', axis=1)
print(final_test.shape)
final_train.shape
# Out:
# (1459, 285)
# (1460, 285)

# %%
final_train
# Out:
#         Id  MSSubClass  ...  SaleCondition_Normal  SaleCondition_Partial
# 0        1          60  ...                     1                      0
# 1        2          20  ...                     1                      0
# 2        3          60  ...                     1                      0
# 3        4          70  ...                     0                      0
# 4        5          60  ...                     1                      0
# ...    ...         ...  ...                   ...                    ...
# 1455  1456          60  ...                     1                      0
# 1456  1457          20  ...                     1                      0
# 1457  1458          70  ...                     1                      0
# 1458  1459          20  ...                     1                      0
# 1459  1460          20  ...                     1                      0
#
# [1460 rows x 285 columns]

# %%
# combining both one_hot_encoded_data and test_hot_encoded_data dataset
combined = pa.concat([one_hot_encoded_data, test_hot_encoded_data])
combined.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# (2919, 304)

# %%
# Spliting combining into train and train having same number of columns
train,test = train_test_split(combined,test_size=0.5,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-acd84d7cecab> in <module>()
# ----> 1 train,test = train_test_split(combined,test_size=0.5,random_state=42)
#
# NameError: name 'train_test_split' is not defined

# %%
print(train.shape)
test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-eee810d01674> in <module>()
# ----> 1 print(train.shape)
#       2 test.shape
#
# NameError: name 'train' is not defined

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = sklearn.preprocessing.MinMaxScaler()
scaler.fit(final_train)
X = scaler.transform(final_train)
Xtest = scaler.transform(final_test)
X.shape
Xtest.shape
# Out:
# (1459, 285)

# %%
X = X[:,1:] #gets rid of the id
Xtest = Xtest[:,1:]
X.shape
# Out:
# (1460, 284)

# %%
plt.scatter(data['MSSubClass'],X[:,0])

# %%
plt.scatter(data['LotFrontage'],X[:,1])

# %%
#Want to look at making more of these straight lines.

# %%
from sklearn import linear_model
clf2 = linear_model.SGDRegressor(max_iter=20000)
clf2.fit(X,y)
clf2.score(X,y)
# Out:
# 0.8922805958814743

# %%
clf2.predict(Xtest)
# Out:
# array([112520.63847552, 148139.73284807, 176396.44301324, ...,
#        163130.73606879, 104870.1460828 , 220936.40999099])
